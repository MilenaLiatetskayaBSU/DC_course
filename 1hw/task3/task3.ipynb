# %%
student={"имя":"Елена", "возраст":19, "курс":2, "предметы":["Английский","Математическая статистика", "Теория вероятности"]}
print("Предметы: ", student["предметы"]) #насколько критичен вывод в таком формате?
# Out:
# Предметы:  ['Английский', 'Математическая статистика', 'Теория вероятности']

# %%
subjects = ", ".join(student["предметы"])
print(f"Предметы: {subjects}")
# Out:
# Предметы: Английский, Математическая статистика, Теория вероятности
