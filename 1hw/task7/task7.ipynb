# %%
number=int(input("Введите число"))
numbers=[]
# Out:
# Введите число 6

# %%
for i in range (1,11):
    numbers.append(number*i)

print(numbers)
# Out:
# [6, 12, 18, 24, 30, 36, 42, 48, 54, 60]

# %%
i=1
for numb in numbers:
    print(i, "   ", numb, "\n")
    i+=1
# Out:
# 1     6
#
# 2     12
#
# 3     18
#
# 4     24
#
# 5     30
#
# 6     36
#
# 7     42
#
# 8     48
#
# 9     54
#
# 10     60
