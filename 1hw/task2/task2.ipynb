# %%
text=input("Введите исходную строку: ")
#для этого примера вводится строка "дс, дз1, вариант 2"
text=text.replace(" ","")
count_without_space = len(text)
print("Количество символов в строке, за исключением пробела: ", count_without_space)
# Out:
# Введите исходную строку:  дс, дз1, вариант 2
# Количество символов в строке, за исключением пробела:  15
