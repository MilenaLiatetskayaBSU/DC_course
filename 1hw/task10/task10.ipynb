# %%
strings = ["1234567","oiuytgfc","oiuyfvbjk","jhgfcvbnl,mnb ","hgfcvbjkl"]
result = [''.join('*' if (i+1)%3==0 else c for i,c in enumerate(s)) for s in strings]
print(result)
# Out:
# ['12*45*7', 'oi*yt*fc', 'oi*yf*bj*', 'jh*fc*bn*,m*b ', 'hg*cv*jk*']
