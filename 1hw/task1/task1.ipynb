# %%
import random

# %%
numbers=random.sample(range(1,101),4)
print("Массив всех 4 чисел: ", numbers, "\nПредпоследнее число: ", numbers[-2])
# Out:
# Массив всех 4 чисел:  [98, 50, 60, 64]
# Предпоследнее число:  60
