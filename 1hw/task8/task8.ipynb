# %%
fruits={
    "банан":"желтый",
    "киви":"зеленый",
    "арбуз":"красный",
    "яблоко":"красный"
}

for fruit, color in fruits.items():
    if 'к' in color.lower():  
        print(f"{fruit}: {color}")
# Out:
# арбуз: красный
# яблоко: красный
