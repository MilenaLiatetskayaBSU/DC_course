# %%
def func(str):
    str=str.lower().replace(" ","")
    for i in range (len(str)//2):
        if str[i]!=str[len(str)-i-1]:
            print("Строка не полиндром")
            return False

    print ("Строка является полиндромом")
    return True

# %%
str=input("Введите строку: ")
#для этого примера вводится строка "mam mam "
result=func(str)
# Out:
# Введите строку:  mam mam
# Строка является полиндромом

# %%
str=input("Введите строку: ")
#для этого примера вводится строка "nmlc hd;"
result=func(str)
# Out:
# Введите строку:  nmlc hd;
# Строка не полиндром
